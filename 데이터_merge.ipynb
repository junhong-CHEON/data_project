# %%
import datetime as dt
from pandas import read_excel
from pandas import read_csv
from pandas import concat
from pandas import merge
import pandas as pd
import numpy as np
from pandas import Series
from pandas import DataFrame

import pymysql
from sqlalchemy import create_engine

# %%
price_apt = read_excel('아파트(매매)_실거래가_(역과의 거리 추가).xlsx',engine='openpyxl')
danji_info = read_excel('서울아파트단지종합_ver1.xlsx',engine='openpyxl')

# %%
price_apt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28598 entries, 0 to 28597
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  28598 non-null  int64
#  1   시군구         28598 non-null  object
#  2   번지          28583 non-null  object
#  3   본번          28594 non-null  float64
#  4   부번          28594 non-null  float64
#  5   단지명         28598 non-null  object
#  6   전용면적(㎡)     28598 non-null  float64
#  7   계약년월        28598 non-null  int64
#  8   계약일         28598 non-null  int64
#  9   거래금액(만원)    28598 non-null  int64
#  10  층           28598 non-null  int64
#  11  건축년도        28598 non-null  int64
#  12  도로명         28598 non-null  object
#  13  해제사유발생일     681 non-null    float64
#  14  경도          28523 non-null  float64
#  15  위도          28523 non-null  float64
#  16  역과의거리(km)   28523 non-null  float64
#  17  호선          28598 non-null  object
#  18  역           28598 non-null  object
# dtypes: float64(7), int64(6), object(6)
# memory usage: 4.1+ MB

# %%
price_apt = price_apt.drop('해제사유발생일', axis=1)

# %%
price_apt= price_apt.dropna(axis=0)

# %%
danji_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2383 entries, 0 to 2382
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   명칭(단지코드)           2383 non-null   object
#  1   사용승인일              2383 non-null   object
#  2   동수 / 세대수           2383 non-null   object
#  3   면적별 세대현황(전용면적 기준)  2383 non-null   object
#  4   연면적                2383 non-null   object
#  5   주거전용면적             2383 non-null   object
#  6   주차대수               2383 non-null   object
#  7   CCTV대수             2383 non-null   float64
#  8   승강기대수              2383 non-null   int64
#  9   시공사 / 시행사          2383 non-null   object
#  10  도로명주소              2307 non-null   object
#  11  법정동주소              2383 non-null   object
#  12  부대·복리시설            2383 non-null   object
#  13  지하철                2383 non-null   object
#  14  버스정류장              2383 non-null   object
#  15  교육시설               2383 non-null   object
#  16  편의시설               2383 non-null   object
#  17  K-apt 가입일          2383 non-null   object
#  18  건물구조               2383 non-null   object
#  19  경비관리               2383 non-null   object
#  20  관리방식               2383 non-null   object
#  21  관리사무소연락처(FAX)      2383 non-null   object
#  22  급수방식               2383 non-null   object
#  23  난방방식               2383 non-null   object
#  24  단지분류               2383 non-null   object
#  25  복도유형               2383 non-null   object
#  26  분양형태               2383 non-null   object
#  27  세대전기계약방식           2383 non-null   object
#  28  소독관리               2383 non-null   object
#  29  수전용량               2383 non-null   object
#  30  승강기관리형태            2383 non-null   object
#  31  일반관리               2383 non-null   object
#  32  전기안전관리자법정선임여부      2383 non-null   object
#  33  주차관제·홈네트워크         2383 non-null   object
#  34  청소관리               2383 non-null   object
#  35  홈페이지주소             2383 non-null   object
#  36  화재수신반방식            2383 non-null   object
# dtypes: float64(1), int64(1), object(35)
# memory usage: 689.0+ KB

# %%
danji_info = danji_info.dropna(axis=0)
danji_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2307 entries, 0 to 2382
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   명칭(단지코드)           2307 non-null   object
#  1   사용승인일              2307 non-null   object
#  2   동수 / 세대수           2307 non-null   object
#  3   면적별 세대현황(전용면적 기준)  2307 non-null   object
#  4   연면적                2307 non-null   object
#  5   주거전용면적             2307 non-null   object
#  6   주차대수               2307 non-null   object
#  7   CCTV대수             2307 non-null   float64
#  8   승강기대수              2307 non-null   int64
#  9   시공사 / 시행사          2307 non-null   object
#  10  도로명주소              2307 non-null   object
#  11  법정동주소              2307 non-null   object
#  12  부대·복리시설            2307 non-null   object
#  13  지하철                2307 non-null   object
#  14  버스정류장              2307 non-null   object
#  15  교육시설               2307 non-null   object
#  16  편의시설               2307 non-null   object
#  17  K-apt 가입일          2307 non-null   object
#  18  건물구조               2307 non-null   object
#  19  경비관리               2307 non-null   object
#  20  관리방식               2307 non-null   object
#  21  관리사무소연락처(FAX)      2307 non-null   object
#  22  급수방식               2307 non-null   object
#  23  난방방식               2307 non-null   object
#  24  단지분류               2307 non-null   object
#  25  복도유형               2307 non-null   object
#  26  분양형태               2307 non-null   object
#  27  세대전기계약방식           2307 non-null   object
#  28  소독관리               2307 non-null   object
#  29  수전용량               2307 non-null   object
#  30  승강기관리형태            2307 non-null   object
#  31  일반관리               2307 non-null   object
#  32  전기안전관리자법정선임여부      2307 non-null   object
#  33  주차관제·홈네트워크         2307 non-null   object
#  34  청소관리               2307 non-null   object
#  35  홈페이지주소             2307 non-null   object
#  36  화재수신반방식            2307 non-null   object
# dtypes: float64(1), int64(1), object(35)
# memory usage: 684.9+ KB

# %%
danji_info = danji_info.reset_index()
danji_info.drop('index', axis = 1)
# Out:
#                    명칭(단지코드)       사용승인일      동수 / 세대수  \
# 0      LG개포자이아파트(A13593901)  2004-06-17    4 / 212 세대
# 1      SH공사대치1단지(A13593908)  1991-11-20   8 / 1623 세대
# 2     개포2차 현대아파트(A13524006)  1986-01-31   13 / 558 세대
# 3        개포경남아파트(A13580602)  1984-03-08    9 / 678 세대
# 4        개포대치2단지(A13524009)  1992-10-14  11 / 1753 세대
# ...                     ...         ...           ...
# 2302    신내의료안심주택(A10027775)  2015-10-29    2 / 222 세대
# 2303     신내중앙하이츠(A13186907)  1996-03-28    5 / 704 세대
# 2304     신내진로아파트(A13187203)  1995-12-06   17 / 818 세대
# 2305        중화극동(A13187501)  1991-04-29    1 / 156 세대
# 2306     중화한신아파트(A13187702)  1997-10-11   9 / 1544 세대
#
#                                       면적별 세대현황(전용면적 기준)           연면적  \
# 0     60㎡ 이하:\n- 세대\n60㎡ ~ 85㎡ 이하:\n- 세대\n85㎡ ~ 135㎡...    60,358.78㎡
# 1     60㎡ 이하:\n1623 세대\n60㎡ ~ 85㎡ 이하:\n- 세대\n85㎡ ~ 1...       73,357㎡
# 2     60㎡ 이하:\n- 세대\n60㎡ ~ 85㎡ 이하:\n112 세대\n85㎡ ~ 13...   92,836.185㎡
# 3     60㎡ 이하:\n- 세대\n60㎡ ~ 85㎡ 이하:\n3 세대\n85㎡ ~ 135㎡...      102,480㎡
# 4     60㎡ 이하:\n1753 세대\n60㎡ ~ 85㎡ 이하:\n- 세대\n85㎡ ~ 1...   105,381.17㎡
# ...                                                 ...           ...
# 2302  60㎡ 이하:\n222 세대\n60㎡ ~ 85㎡ 이하:\n- 세대\n85㎡ ~ 13...    13,099.58㎡
# 2303  60㎡ 이하:\n- 세대\n60㎡ ~ 85㎡ 이하:\n704 세대\n85㎡ ~ 13...    78,861.83㎡
# 2304  60㎡ 이하:\n- 세대\n60㎡ ~ 85㎡ 이하:\n- 세대\n85㎡ ~ 135㎡...  142,806.002㎡
# 2305  60㎡ 이하:\n- 세대\n60㎡ ~ 85㎡ 이하:\n156 세대\n85㎡ ~ 13...    17,030.12㎡
# 2306  60㎡ 이하:\n892 세대\n60㎡ ~ 85㎡ 이하:\n652 세대\n85㎡ ~ ...      144,301㎡
#
#            주거전용면적                         주차대수  CCTV대수  승강기대수  \
# 0      32,275.48㎡     지상: 19 / 지하: 483(총:502대)    58.0      6
# 1      46,586.33㎡      지상: 389 / 지하: 0(총:389대)    96.0     12
# 2         75,527㎡      지상: 500 / 지하: 0(총:500대)    41.0     31
# 3     92,546.465㎡      지상: 747 / 지하: 0(총:747대)   102.0     26
# 4       71,852.9㎡     지상: 438 / 지하: 73(총:511대)   100.0     14
# ...           ...                          ...     ...    ...
# 2302    5,535.57㎡      지상: 25 / 지하: 90(총:115대)    61.0      5
# 2303   59,818.88㎡    지상: 295 / 지하: 145(총:440대)   108.0     25
# 2304   91,553.06㎡   지상: 378 / 지하: 875(총:1253대)   212.0     36
# 2305   13,006.25㎡        지상: 72 / 지하: 0(총:72대)    23.0      6
# 2306  105,896.94㎡  지상: 475 / 지하: 1024(총:1499대)   160.0     24
#
#                         시공사 / 시행사  ... 세대전기계약방식  \
# 0                     화엄건설 / LG건설  ...     종합계약
# 1                     SH공사 / 남강개발  ...       기타
# 2           현대산업개발(주) / 현대산업개발(주)  ...     종합계약
# 3                     경남건설 / 경남건설  ...     단일계약
# 4     성원건설.진덕산업주식회사 / 서울특별시도시개발공사  ...     단일계약
# ...                           ...  ...      ...
# 2302                SD종합건설 / SH공사  ...     단일계약
# 2303               중앙건설(주) / 한전조합  ...     단일계약
# 2304                      진로 / 진로  ...     종합계약
# 2305                  극동건설 / 극동건설  ...     단일계약
# 2306   한신공영 / 신천실업(주),청법지역주택외8개조합  ...     단일계약
#
#                                          소독관리     수전용량 승강기관리형태  \
# 0         관리방식: 위탁관리 / 연간소독횟수: 12 / 소독방법: 분무식  1600 Kw    위탁관리
# 1     관리방식: 위탁관리 / 연간소독횟수: 12 / 소독방법: 분무식,독이식   950 Kw    위탁관리
# 2          관리방식: 위탁관리 / 연간소독횟수: 4 / 소독방법: 분무식  1750 Kw    위탁관리
# 3      관리방식: 위탁관리 / 연간소독횟수: 4 / 소독방법: 도포식,분무식  2900 Kw    위탁관리
# 4     관리방식: 위탁관리 / 연간소독횟수: 12 / 소독방법: 도포식,독이식  2900 Kw    위탁관리
# ...                                       ...      ...     ...
# 2302       관리방식: 위탁관리 / 연간소독횟수: 4 / 소독방법: 분무식   500 Kw    위탁관리
# 2303  관리방식: 위탁관리 / 연간소독횟수: 12 / 소독방법: 도포식,분무식  1550 Kw    위탁관리
# 2304         관리방식: 위탁관리 / 연간소독횟수: 4 / 소독방법: -  2400 Kw    위탁관리
# 2305       관리방식: 위탁관리 / 연간소독횟수: 4 / 소독방법: 도포식   450 Kw    위탁관리
# 2306  관리방식: 위탁관리 / 연간소독횟수: 12 / 소독방법: 도포식,분무식  4150 Kw    위탁관리
#
#                                          일반관리 전기안전관리자법정선임여부 주차관제·홈네트워크  \
# 0                관리방식: 자치관리 / 인원: 6 / 계약업체: -          상주선임          무
# 1        관리방식: 위탁관리 / 인원: 9 / 계약업체: (주)미래에이비엠          상주선임          무
# 2                관리방식: 자치관리 / 인원: 8 / 계약업체: -          상주선임          무
# 3          관리방식: 위탁관리 / 인원: 9 / 계약업체: 우리관리(주)            기타          무
# 4      관리방식: 위탁관리 / 인원: 12 / 계약업체: 남경종합관리(주)l          상주선임          무
# ...                                       ...           ...        ...
# 2302     관리방식: 위탁관리 / 인원: 3 / 계약업체: (주)두온자산관리          위탁선임          유
# 2303     관리방식: 위탁관리 / 인원: 6 / 계약업체: 국제경보산업(주)          상주선임          무
# 2304  관리방식: 위탁관리 / 인원: 11 / 계약업체: 한국주택시설관리(주)          상주선임          무
# 2305         관리방식: 위탁관리 / 인원: 2 / 계약업체: 신현대관리          위탁선임          무
# 2306    관리방식: 위탁관리 / 인원: 10 / 계약업체: 인덕종합관리(주)          상주선임          무
#
#                                           청소관리  \
# 0      관리방식: 위탁관리 / 인원: 4 / 음식물처리방법: 음식물쓰레기종량제
# 1      관리방식: 위탁관리 / 인원: 9 / 음식물처리방법: 음식물쓰레기종량제
# 2      관리방식: 위탁관리 / 인원: 5 / 음식물처리방법: 음식물쓰레기종량제
# 3      관리방식: 위탁관리 / 인원: 8 / 음식물처리방법: 음식물쓰레기종량제
# 4     관리방식: 위탁관리 / 인원: 12 / 음식물처리방법: 음식물쓰레기종량제
# ...                                        ...
# 2302          관리방식: 위탁관리 / 인원: 1 / 음식물처리방법: 기타
# 2303   관리방식: 위탁관리 / 인원: 7 / 음식물처리방법: 음식물쓰레기종량제
# 2304   관리방식: 위탁관리 / 인원: 8 / 음식물처리방법: 음식물쓰레기종량제
# 2305   관리방식: 위탁관리 / 인원: 2 / 음식물처리방법: 음식물쓰레기종량제
# 2306  관리방식: 위탁관리 / 인원: 14 / 음식물처리방법: 음식물쓰레기종량제
#
#                                             홈페이지주소 화재수신반방식
# 0                                      http://test      R형
# 1     http://happy.i-sh.co.kr/main.do?deptid=20167     GR형
# 2                           http://현대2차.apti.co.kr      P형
# 3                                                -      R형
# 4                                                -      P형
# ...                                            ...     ...
# 2302                                             -      R형
# 2303                                             -      P형
# 2304                                             -      기타
# 2305                                             -      P형
# 2306                                             -      R형
#
# [2307 rows x 37 columns]

# %%
price_apt['도로명'] = price_apt['도로명'].astype('str')
danji_info['도로명주소'] = danji_info['도로명주소'].astype('str')

# %%
price_apt['도로명'] = price_apt['도로명'].str.replace(' ','')

# %%
price_apt['도로명']
# Out:
# 0           언주로103
# 1             언주로3
# 2           개포로264
# 3           개포로264
# 4           개포로264
#            ...
# 28593       동일로752
# 28594       동일로752
# 28595    동일로144길74
# 28596    동일로144길74
# 28597    동일로144길74
# Name: 도로명, Length: 28508, dtype: object

# %%
filter_list = danji_info['도로명주소'].str.rfind(' ') 
for i,v in enumerate(filter_list):
    tok = danji_info['도로명주소'][i].rfind(' ',0,v)
    danji_info['도로명주소'][i] = danji_info['도로명주소'][i][tok+1 :]
# Out:
# <ipython-input-12-81c4f6f5c484>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   danji_info['도로명주소'][i] = danji_info['도로명주소'][i][tok+1 :]

# %%
danji_info['도로명주소'] = danji_info['도로명주소'].str.replace(' ','')

# %%
merge_df = merge(danji_info, price_apt, how = 'left', left_on = '도로명주소', right_on='도로명')

# %%
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20440 entries, 0 to 20439
# Data columns (total 56 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              20440 non-null  int64
#  1   명칭(단지코드)           20440 non-null  object
#  2   사용승인일              20440 non-null  object
#  3   동수 / 세대수           20440 non-null  object
#  4   면적별 세대현황(전용면적 기준)  20440 non-null  object
#  5   연면적                20440 non-null  object
#  6   주거전용면적             20440 non-null  object
#  7   주차대수               20440 non-null  object
#  8   CCTV대수             20440 non-null  float64
#  9   승강기대수              20440 non-null  int64
#  10  시공사 / 시행사          20440 non-null  object
#  11  도로명주소              20440 non-null  object
#  12  법정동주소              20440 non-null  object
#  13  부대·복리시설            20440 non-null  object
#  14  지하철                20440 non-null  object
#  15  버스정류장              20440 non-null  object
#  16  교육시설               20440 non-null  object
#  17  편의시설               20440 non-null  object
#  18  K-apt 가입일          20440 non-null  object
#  19  건물구조               20440 non-null  object
#  20  경비관리               20440 non-null  object
#  21  관리방식               20440 non-null  object
#  22  관리사무소연락처(FAX)      20440 non-null  object
#  23  급수방식               20440 non-null  object
#  24  난방방식               20440 non-null  object
#  25  단지분류               20440 non-null  object
#  26  복도유형               20440 non-null  object
#  27  분양형태               20440 non-null  object
#  28  세대전기계약방식           20440 non-null  object
#  29  소독관리               20440 non-null  object
#  30  수전용량               20440 non-null  object
#  31  승강기관리형태            20440 non-null  object
#  32  일반관리               20440 non-null  object
#  33  전기안전관리자법정선임여부      20440 non-null  object
#  34  주차관제·홈네트워크         20440 non-null  object
#  35  청소관리               20440 non-null  object
#  36  홈페이지주소             20440 non-null  object
#  37  화재수신반방식            20440 non-null  object
#  38  Unnamed: 0         20133 non-null  float64
#  39  시군구                20133 non-null  object
#  40  번지                 20133 non-null  object
#  41  본번                 20133 non-null  float64
#  42  부번                 20133 non-null  float64
#  43  단지명                20133 non-null  object
#  44  전용면적(㎡)            20133 non-null  float64
#  45  계약년월               20133 non-null  float64
#  46  계약일                20133 non-null  float64
#  47  거래금액(만원)           20133 non-null  float64
#  48  층                  20133 non-null  float64
#  49  건축년도               20133 non-null  float64
#  50  도로명                20133 non-null  object
#  51  경도                 20133 non-null  float64
#  52  위도                 20133 non-null  float64
#  53  역과의거리(km)          20133 non-null  float64
#  54  호선                 20133 non-null  object
#  55  역                  20133 non-null  object
# dtypes: float64(13), int64(2), object(41)
# memory usage: 8.9+ MB

# %%
merge_df = merge_df.dropna(axis = 0)

# %%
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20133 entries, 0 to 20439
# Data columns (total 56 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              20133 non-null  int64
#  1   명칭(단지코드)           20133 non-null  object
#  2   사용승인일              20133 non-null  object
#  3   동수 / 세대수           20133 non-null  object
#  4   면적별 세대현황(전용면적 기준)  20133 non-null  object
#  5   연면적                20133 non-null  object
#  6   주거전용면적             20133 non-null  object
#  7   주차대수               20133 non-null  object
#  8   CCTV대수             20133 non-null  float64
#  9   승강기대수              20133 non-null  int64
#  10  시공사 / 시행사          20133 non-null  object
#  11  도로명주소              20133 non-null  object
#  12  법정동주소              20133 non-null  object
#  13  부대·복리시설            20133 non-null  object
#  14  지하철                20133 non-null  object
#  15  버스정류장              20133 non-null  object
#  16  교육시설               20133 non-null  object
#  17  편의시설               20133 non-null  object
#  18  K-apt 가입일          20133 non-null  object
#  19  건물구조               20133 non-null  object
#  20  경비관리               20133 non-null  object
#  21  관리방식               20133 non-null  object
#  22  관리사무소연락처(FAX)      20133 non-null  object
#  23  급수방식               20133 non-null  object
#  24  난방방식               20133 non-null  object
#  25  단지분류               20133 non-null  object
#  26  복도유형               20133 non-null  object
#  27  분양형태               20133 non-null  object
#  28  세대전기계약방식           20133 non-null  object
#  29  소독관리               20133 non-null  object
#  30  수전용량               20133 non-null  object
#  31  승강기관리형태            20133 non-null  object
#  32  일반관리               20133 non-null  object
#  33  전기안전관리자법정선임여부      20133 non-null  object
#  34  주차관제·홈네트워크         20133 non-null  object
#  35  청소관리               20133 non-null  object
#  36  홈페이지주소             20133 non-null  object
#  37  화재수신반방식            20133 non-null  object
#  38  Unnamed: 0         20133 non-null  float64
#  39  시군구                20133 non-null  object
#  40  번지                 20133 non-null  object
#  41  본번                 20133 non-null  float64
#  42  부번                 20133 non-null  float64
#  43  단지명                20133 non-null  object
#  44  전용면적(㎡)            20133 non-null  float64
#  45  계약년월               20133 non-null  float64
#  46  계약일                20133 non-null  float64
#  47  거래금액(만원)           20133 non-null  float64
#  48  층                  20133 non-null  float64
#  49  건축년도               20133 non-null  float64
#  50  도로명                20133 non-null  object
#  51  경도                 20133 non-null  float64
#  52  위도                 20133 non-null  float64
#  53  역과의거리(km)          20133 non-null  float64
#  54  호선                 20133 non-null  object
#  55  역                  20133 non-null  object
# dtypes: float64(13), int64(2), object(41)
# memory usage: 8.8+ MB

# %%
HOSTNAME = 'izen.cxppaurfujpc.ap-northeast-2.rds.amazonaws.com'
PORT = 3306
USERNAME = 'admin'
PASSWORD = '1234567890'
DATABASE = 'project1'
CHARSET1 = 'utf8'
CHARSET2= 'utf-8'

# %%
con_str_fmt = 'mysql+mysqldb://{0}:{1}@{2}:{3}/{4}?charset={5}'
con_str = con_str_fmt.format(USERNAME, PASSWORD, HOSTNAME, PORT, DATABASE, CHARSET1)
con_str
# Out:
# 'mysql+mysqldb://admin:1234567890@izen.cxppaurfujpc.ap-northeast-2.rds.amazonaws.com:3306/project1?charset=utf8'

# %%
pymysql.install_as_MySQLdb()
import MySQLdb

# %%
engine = create_engine(con_str, encoding=CHARSET2)
conn = engine.connect()

# %%
merge_df.to_sql(name='add_distance', con = conn, if_exists='replace', index=True)
