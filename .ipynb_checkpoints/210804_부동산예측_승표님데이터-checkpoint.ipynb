# %%
# 패키지 참조하기
import pymysql
from sqlalchemy import create_engine
import pandas as pd
from pandas import DataFrame
from matplotlib import pyplot
import datetime as dt
from pandas import read_excel
from pandas import read_csv
from pandas import concat
from pandas import merge
import numpy as np
from pandas import Series

# 모델을 구성하기위한 객체
from tensorflow.keras.models import Sequential
# 모델에 학습층을 쌓기 위한 클래스
from tensorflow.keras.layers import Dense
# 데이터를 훈련용과 테스트용으로 나누는 기능
from sklearn.model_selection import train_test_split

# 학습에 대한 콜백함수 처리용 패키지 참조
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import ModelCheckpoint

# 표준화 처리 패키지
from sklearn.preprocessing import StandardScaler

# 회귀분석을 수행하는 통계 패키지 (머신러닝과는 연관 없음)
from statsmodels.formula.api import ols

# 보스턴 집값 데이터를 로드하기 위한 객체 참조
from sklearn import datasets

from sklearn.decomposition import PCA # 주성분 분석용 패키지
from pca import pca # 주성분 분석 결과 시각화를 위한 패키지 
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# 데이터베이스 연동에 필요한 접속 정보 변수 초기화
HOSTNAME = "izen.cxppaurfujpc.ap-northeast-2.rds.amazonaws.com"
PORT = 3306
USERNAME = "admin"
PASSWORD = "1234567890"
DATABASE = "project1"
CHARSET1 = "utf8"      # MySQL에서 사용할 캐릭터셋 이름
CHARSET2 = "utf-8"     # Python에서 사용할 캐릭터셋 이름

# %%
# 접속 문자열 생성하기
# SQLAlchemy를 통한 데이터베이스 접속은 아래와 같은 형식의 문자열을 요구한다
# mysql+mysqldb://아이디:비밀번호@DB서버주소:포트번호/DB이름?CHARSET=인코딩
# 접속 문자열을 생성하기 위해 필요한 정보를 변수로 초기화하고 문자열의 FORMAT() 함수를 활용하여
# 접속문자열을 생성한다.
# 접속문자열 생성
con_str_fmt = "mysql+mysqldb://{0}:{1}@{2}:{3}/{4}?charset={5}"
con_str = con_str_fmt.format(USERNAME,PASSWORD,HOSTNAME,PORT,DATABASE,CHARSET1)
con_str
# Out:
# 'mysql+mysqldb://admin:1234567890@izen.cxppaurfujpc.ap-northeast-2.rds.amazonaws.com:3306/project1?charset=utf8'

# %%
pymysql.install_as_MySQLdb()
import MySQLdb

# %%
engine = create_engine(con_str, encoding=CHARSET2)
conn = engine.connect()

# %%
df = pd.read_sql_table('aptinfo1_table', index_col = 'index', con=conn)
df
# Out:
#        level_0    건축년도  전체세대수 135㎡초과세대수  전철역의수 지하철역과의거리(분 주차대수  CCTV대수  \
# index
# 1            0  2004.0    212       128      1         10  502    58.0
# 2            1  2004.0    212       128      1         10  502    58.0
# 3            2  2004.0    212       128      1         10  502    58.0
# 4            3  2004.0    212       128      1         10  502    58.0
# 5            4  2004.0    212       128      1         10  502    58.0
# ...        ...     ...    ...       ...    ...        ...  ...     ...
# 20436    20435  1998.0    544        \n      3       None  499   160.0
# 20437    20436  1998.0    544        \n      3       None  499   160.0
# 20438    20437  1998.0    544        \n      3       None  499   160.0
# 20439    20438  1998.0    544        \n      3       None  499   160.0
# 20440    20439  1998.0    544        \n      3       None  499   160.0
#
#              연면적     주거전용면적  편의시설수  부대·복리시설수     층  전용면적(㎡)  거래금액(만원)
# index
# ...

# %%
df_copy = df.copy()

# %%
df_copy.info()
df_copy.drop(['level_0'], axis=1, inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20440 entries, 1 to 20440
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   level_0     20440 non-null  int64
#  1   건축년도        20133 non-null  float64
#  2   전체세대수       20440 non-null  int64
#  3   135㎡초과세대수   20440 non-null  object
#  4   전철역의수       20440 non-null  int64
#  5   지하철역과의거리(분  19693 non-null  object
#  6   주차대수        20440 non-null  object
#  7   CCTV대수      20440 non-null  float64
#  8   연면적         20440 non-null  float64
#  9   주거전용면적      20440 non-null  float64
#  10  편의시설수       20440 non-null  int64
#  11  부대·복리시설수    20440 non-null  int64
#  12  층           20133 non-null  float64
#  13  전용면적(㎡)     20133 non-null  float64
#  14  거래금액(만원)    20133 non-null  float64
# dtypes: float64(7), int64(5), object(3)
# memory usage: 2.5+ MB

# %%
df_copy.rename(columns={'135㎡초과세대수':'135초과세대수','전용면적(㎡)':'전용면적', '거래금액(만원)':'거래금액', '지하철역과의거리(분':'지하철까지' }, inplace=True)
df_copy
# Out:
#          건축년도  전체세대수 135초과세대수  전철역의수 지하철까지 주차대수  CCTV대수        연면적     주거전용면적  \
# index
# 1      2004.0    212      128      1    10  502    58.0   60358.78   32275.48
# 2      2004.0    212      128      1    10  502    58.0   60358.78   32275.48
# 3      2004.0    212      128      1    10  502    58.0   60358.78   32275.48
# 4      2004.0    212      128      1    10  502    58.0   60358.78   32275.48
# 5      2004.0    212      128      1    10  502    58.0   60358.78   32275.48
# ...       ...    ...      ...    ...   ...  ...     ...        ...        ...
# 20436  1998.0    544       \n      3  None  499   160.0  144301.00  105896.94
# 20437  1998.0    544       \n      3  None  499   160.0  144301.00  105896.94
# 20438  1998.0    544       \n      3  None  499   160.0  144301.00  105896.94
# 20439  1998.0    544       \n      3  None  499   160.0  144301.00  105896.94
# 20440  1998.0    544       \n      3  None  499   160.0  144301.00  105896.94
#
# ...

# %%
# 135초과세대수 \n 값을 0으로 바꾼다

list7 = []
for i in df_copy['135초과세대수']:
    abc = i.replace('\n','0')
    list7.append(abc)
df_copy['135초과세대수'] = list7

# %%
df_copy
# Out:
#          건축년도  전체세대수 135초과세대수  전철역의수 지하철까지 주차대수  CCTV대수        연면적     주거전용면적  \
# index
# 1      2004.0    212      128      1    10  502    58.0   60358.78   32275.48
# 2      2004.0    212      128      1    10  502    58.0   60358.78   32275.48
# 3      2004.0    212      128      1    10  502    58.0   60358.78   32275.48
# 4      2004.0    212      128      1    10  502    58.0   60358.78   32275.48
# 5      2004.0    212      128      1    10  502    58.0   60358.78   32275.48
# ...       ...    ...      ...    ...   ...  ...     ...        ...        ...
# 20436  1998.0    544        0      3  None  499   160.0  144301.00  105896.94
# 20437  1998.0    544        0      3  None  499   160.0  144301.00  105896.94
# 20438  1998.0    544        0      3  None  499   160.0  144301.00  105896.94
# 20439  1998.0    544        0      3  None  499   160.0  144301.00  105896.94
# 20440  1998.0    544        0      3  None  499   160.0  144301.00  105896.94
#
# ...

# %%
list8 = []
for i in df_copy['주차대수']:
    abc = i.replace(':','').replace('총','')
    list8.append(abc)
df_copy['주차대수'] = list8

# %%
uni = df_copy['주차대수'].unique()
uni
# Out:
# array(['502', '389', '500', '747', '511', '961', '419', '138', '652',
#        '100', '453', '330', '276', '103', '153', '176', '239', '580',
#        '684', '572', '189', '200', '645', '230', '411', '210', '804',
#        '997', '238', '59', '468', '171', '498', '655', '686', '119',
#        '461', '670', '21', '280', '599', '180', '548', '370', '126',
#        '338', '123', '435', '220', '222', '414', '441', '152', '156',
#        '510', '808', '77', '285', '342', '654', '266', '291', '743',
#        '520', '484', '378', '297', '130', '281', '303', '275', '514',
#        '341', '247', '850', '420', '457', '995', '398', '407', '439',
#        '148', '950', '534', '314', '764', '0', '325', '742', '344', '410',
#        '667', '800', '596', '941', '465', '350', '387', '289', '626',
#        '582', '852', '771', '552', '228', '334', '208', '53', '665',
#        '914', '615', '166', '121', '588', '213', '346', '697', '300',
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20440 entries, 1 to 20440
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   건축년도      20133 non-null  float64
#  1   전체세대수     20440 non-null  int64
#  2   135초과세대수  20440 non-null  object
#  3   전철역의수     20440 non-null  int64
#  4   지하철까지     19693 non-null  object
#  5   주차대수      20440 non-null  object
#  6   CCTV대수    20440 non-null  float64
#  7   연면적       20440 non-null  float64
#  8   주거전용면적    20440 non-null  float64
#  9   편의시설수     20440 non-null  int64
#  10  부대·복리시설수  20440 non-null  int64
#  11  층         20133 non-null  float64
#  12  전용면적      20133 non-null  float64
#  13  거래금액      20133 non-null  float64
# dtypes: float64(7), int64(4), object(3)
# memory usage: 2.3+ MB

# %%
df_copy['135초과세대수'] = df_copy['135초과세대수'].astype('int64')


df_copy['지하철까지'] = df_copy['지하철까지'].astype('category').cat.rename_categories({None:0, '5':1, '10':2, '15':3, '20':4, '20분초과' : 6})


df_copy['주차대수'] = df_copy['주차대수'].astype('int64')

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20440 entries, 1 to 20440
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   건축년도      20133 non-null  float64
#  1   전체세대수     20440 non-null  int64
#  2   135초과세대수  20440 non-null  int64
#  3   전철역의수     20440 non-null  int64
#  4   지하철까지     19693 non-null  category
#  5   주차대수      20440 non-null  int64
#  6   CCTV대수    20440 non-null  float64
#  7   연면적       20440 non-null  float64
#  8   주거전용면적    20440 non-null  float64
#  9   편의시설수     20440 non-null  int64
#  10  부대·복리시설수  20440 non-null  int64
#  11  층         20133 non-null  float64
#  12  전용면적      20133 non-null  float64
#  13  거래금액      20133 non-null  float64
# dtypes: category(1), float64(7), int64(6)
# memory usage: 2.2 MB

# %%
df_copy.columns
# Out:
# Index(['건축년도', '전체세대수', '135초과세대수', '전철역의수', '지하철까지', '주차대수', 'CCTV대수', '연면적',
#        '주거전용면적', '편의시설수', '부대·복리시설수', '층', '전용면적', '거래금액'],
#       dtype='object')

# %%
df_copy.dropna(inplace=True)

# %%
df_copy.isna().sum()
# Out:
# 건축년도        0
# 전체세대수       0
# 135초과세대수    0
# 전철역의수       0
# 지하철까지       0
# 주차대수        0
# CCTV대수      0
# 연면적         0
# 주거전용면적      0
# 편의시설수       0
# 부대·복리시설수    0
# 층           0
# 전용면적        0
# 거래금액        0
# dtype: int64

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19410 entries, 1 to 20391
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   건축년도      19410 non-null  float64
#  1   전체세대수     19410 non-null  int64
#  2   135초과세대수  19410 non-null  int64
#  3   전철역의수     19410 non-null  int64
#  4   지하철까지     19410 non-null  category
#  5   주차대수      19410 non-null  int64
#  6   CCTV대수    19410 non-null  float64
#  7   연면적       19410 non-null  float64
#  8   주거전용면적    19410 non-null  float64
#  9   편의시설수     19410 non-null  int64
#  10  부대·복리시설수  19410 non-null  int64
#  11  층         19410 non-null  float64
#  12  전용면적      19410 non-null  float64
#  13  거래금액      19410 non-null  float64
# dtypes: category(1), float64(7), int64(6)
# memory usage: 2.1 MB

# %%
x_train_set = df_copy.filter(['건축년도', '전체세대수', '135초과세대수', '전철역의수', '지하철까지', '주차대수', 'CCTV대수', '연면적',
       '주거전용면적', '편의시설수', '부대·복리시설수', '층', '전용면적'])
y_train_set = df_copy.filter(['거래금액'])
print("훈련데이터 크기:", x_train_set.shape, "/ 레이블 크기:", y_train_set.shape)
x_train_set
# Out:
# 훈련데이터 크기: (19410, 13) / 레이블 크기: (19410, 1)
#          건축년도  전체세대수  135초과세대수  전철역의수 지하철까지  주차대수  CCTV대수       연면적    주거전용면적  \
# index
# 1      2004.0    212       128      1     2   502    58.0  60358.78  32275.48
# 2      2004.0    212       128      1     2   502    58.0  60358.78  32275.48
# 3      2004.0    212       128      1     2   502    58.0  60358.78  32275.48
# 4      2004.0    212       128      1     2   502    58.0  60358.78  32275.48
# 5      2004.0    212       128      1     2   502    58.0  60358.78  32275.48
# ...       ...    ...       ...    ...   ...   ...     ...       ...       ...
# 20386  1996.0    704         0      4     2   440   108.0  78861.83  59818.88
# 20388  1991.0    156         0      2     2    72    23.0  17030.12  13006.25
# 20389  1991.0    156         0      2     2    72    23.0  17030.12  13006.25
# 20390  1991.0    156         0      2     2    72    23.0  17030.12  13006.25
# ...

# %%
# 훈련데이터와 테스트 데이터 분류
x_train, x_test, y_train, y_test = train_test_split(x_train_set, y_train_set, test_size=0.33, random_state=777)
print("훈련용 데이터셋 크기: %d, 검증용 데이터셋 크기: %d" % (len(x_train), len(x_test)))
# Out:
# 훈련용 데이터셋 크기: 13004, 검증용 데이터셋 크기: 6406

# %%
scaler = StandardScaler()
std_x_train = DataFrame(scaler.fit_transform(x_train), columns=x_train.columns)
std_x_test = DataFrame(scaler.transform(x_test), columns=x_test.columns)
std_x_train.head()
std_x_test.head()
# Out:
#        건축년도     전체세대수  135초과세대수     전철역의수     지하철까지      주차대수    CCTV대수  \
# 0  0.307781 -0.752001 -0.306924  1.874850 -0.245619 -0.932975 -0.453113
# 1  1.253646  0.516452  2.950801  0.559116 -1.040153 -0.769603 -0.019367
# 2 -0.743181 -0.316214 -0.306924 -0.756618 -0.245619  0.320811 -0.386137
# 3  2.094416 -1.627467 -0.306924 -0.756618 -1.040153 -0.169305  5.447108
# 4  0.412877  0.049537 -0.306924 -0.756618  0.548915  0.924908 -0.303215
#
#         연면적    주거전용면적     편의시설수  부대·복리시설수         층      전용면적
# 0 -0.101060 -0.734640  0.358569 -1.565071 -0.267098 -1.011979
# 1  0.005315 -0.077376  0.358569  0.741230  3.336421  2.213652
# 2 -0.054589 -0.294098  0.358569  0.279970 -0.717538 -0.878321
# 3  0.396144  2.315577 -0.311956  2.125011 -0.417245  0.306890
# 4 -0.049474 -0.378295  2.370142 -0.181290  1.684808 -0.528138

# %%
model = pca(n_components=len(x_train.columns))
fit = model.fit_transform(std_x_train)
fit['topfeat']
# Out:
# [pca] >Processing dataframe..
# [pca] >The PCA reduction is performed on the [13] columns of the input dataframe.
# [pca] >Fitting using PCA..
# [pca] >Computing loadings and PCs..
# [pca] >Computing explained variance..
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[13]
# [pca] >Outlier detection using SPE/DmodX with n_std=[2]
#       PC   feature   loading  type
# 0    PC1    CCTV대수  0.522300  best
# 1    PC2     편의시설수  0.526673  best
# 2    PC3      전용면적 -0.471692  best
# 3    PC4      주차대수 -0.625775  best
# 4    PC5     전철역의수 -0.752175  best
# 5    PC6       연면적  0.702801  best
# 6    PC7       연면적  0.559025  best
# 7    PC8         층 -0.624848  best
# 8    PC9     전체세대수  0.596228  best
# 9   PC10     편의시설수  0.651695  best
# 10  PC11  135초과세대수  0.641362  best
# 11  PC12      건축년도  0.606721  best
# 12  PC13    CCTV대수  0.700723  best
# 13   PC6     지하철까지  0.625879  weak
# 14  PC13    주거전용면적 -0.654711  weak
# ...

# %%
pca_x_train = std_x_train.drop(['지하철까지','주거전용면적','부대·복리시설수'], axis=1)
pca_x_test = std_x_test.drop(['지하철까지','주거전용면적','부대·복리시설수'], axis=1)

# %%
# 데이터가 단순하고 개수가 적다면 과대적합이 발생할 확률이 높기 때문에 주의하면서 적절한 크기의 모델층을 쌓아야 한다.
model = Sequential()
# 1차원의 데이터를 입력으로 받고, 64개의 출력을 가지는 첫 번째 Dense 층
model.add(Dense(64, activation = 'relu', input_shape = (10, )))
model.add(Dense(32, activation = 'relu'))
# 하나의 값을 출력
# -> 정답의 범위가 정해지지 않기 때문에 활성화 함수는 linear
# -> linear는 기본값이므로 생략 가능함.
model.add(Dense(1, activation='linear'))

model.compile(optimizer='adam', loss = 'mse', metrics = ['mae'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 64)                704
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# ...
# Total params: 2,817
# Trainable params: 2,817
# Non-trainable params: 0
# _________________________________________________________________

# %%
result = model.fit(pca_x_train, y_train, epochs = 500, validation_data = (pca_x_test, y_test), callbacks = [
    EarlyStopping(monitor = 'val_loss', patience=5, verbose = 1),
    ReduceLROnPlateau(monitor= "val_loss", patience=3, factor = 0.5, min_lr=0.0001, verbose=1)
    #ModelCheckpoint(filepath = 'bostun_housing.h5', monitor = 'val_loss', verbose=1, save_best_only = True)
])
result.history.keys()
# Out:
# Epoch 1/500
# 407/407 [==============================] - 2s 5ms/step - loss: 17136262144.0000 - mae: 109637.6719 - val_loss: 17019986944.0000 - val_mae: 109268.1797
# Epoch 2/500
# 407/407 [==============================] - 2s 4ms/step - loss: 16396194816.0000 - mae: 107193.2500 - val_loss: 15568541696.0000 - val_mae: 104446.3047
# Epoch 3/500
# 407/407 [==============================] - 2s 5ms/step - loss: 14104711168.0000 - mae: 99382.7500 - val_loss: 12538704896.0000 - val_mae: 93416.2734
# Epoch 4/500
# 407/407 [==============================] - 2s 4ms/step - loss: 10522808320.0000 - mae: 85079.8281 - val_loss: 8843078656.0000 - val_mae: 76232.8125
# Epoch 5/500
# 407/407 [==============================] - 2s 4ms/step - loss: 6970433536.0000 - mae: 66896.8203 - val_loss: 6027028992.0000 - val_mae: 58733.1016
# Epoch 6/500
# 407/407 [==============================] - 2s 4ms/step - loss: 4649868800.0000 - mae: 51946.6289 - val_loss: 4523316736.0000 - val_mae: 47105.2734
# ...

# %%
result_df = DataFrame(result.history)
result_df['epochs'] = result_df.index+1
result_df.set_index('epochs', inplace=True)
result_df
# Out:
#                 loss            mae      val_loss        val_mae        lr
# epochs
# 1       1.713626e+10  109637.671875  1.701999e+10  109268.179688  0.001000
# 2       1.639619e+10  107193.250000  1.556854e+10  104446.304688  0.001000
# 3       1.410471e+10   99382.750000  1.253870e+10   93416.273438  0.001000
# 4       1.052281e+10   85079.828125  8.843079e+09   76232.812500  0.001000
# 5       6.970434e+09   66896.820312  6.027029e+09   58733.101562  0.001000
# ...              ...            ...           ...            ...       ...
# 496     1.524811e+09   27525.484375  1.637819e+09   28579.361328  0.000125
# 497     1.524656e+09   27507.587891  1.637974e+09   28583.748047  0.000125
# 498     1.524474e+09   27507.123047  1.637577e+09   28580.166016  0.000125
# 499     1.524355e+09   27509.425781  1.638045e+09   28592.232422  0.000125
# 500     1.524212e+09   27514.394531  1.637490e+09   28579.056641  0.000125
#
# [500 rows x 5 columns]

# %%
# 그래프 기본 설정
# ----------------------------------------
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams["font.size"] = 16
plt.rcParams['axes.unicode_minus'] = False

# 그래프를 그리기 위한 객체 생성
# ----------------------------------------
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 5), dpi=150)

# 1) 훈련 및 검증 손실 그리기
# ----------------------------------------
sns.lineplot(x=result_df.index, y='loss', data=result_df, color='blue', label='훈련 손실률', ax=ax1)
sns.lineplot(x=result_df.index, y='val_loss', data=result_df, color='orange', label='검증 손실률', ax=ax1)
ax1.set_title('훈련 및 검증 손실률')
ax1.set_xlabel('반복회차')
ax1.set_ylabel('손실률')
ax1.grid()
ax1.legend()

# 2) 훈련 및 검증 절대오차 그리기
# ----------------------------------------
sns.lineplot(x=result_df.index, y='mae', data=result_df, color = 'blue', label = '훈련 절대오차', ax=ax2)
sns.lineplot(x=result_df.index, y='val_mae', data=result_df, color = 'orange', label = '검증 절대오차', ax=ax2)
ax2.set_title('훈련 및 검증 절대오차')
ax2.set_xlabel('반복회차')
ax2.set_ylabel('정확도')
ax2.grid()
ax2.legend()

plt.show()
plt.close()

# %%
evaluate = model.evaluate(pca_x_test, y_test)
print("최종 손실률: %f, 최종 절대오차: %f" % (evaluate[0], evaluate[1]))
# Out:
# 201/201 [==============================] - 0s 2ms/step - loss: 1637490048.0000 - mae: 28579.0566
# 최종 손실률: 1637490048.000000, 최종 절대오차: 28579.056641

# %%
test_predictions = model.predict(pca_x_test)
test_predictions
# Out:
# array([[ 60073.45 ],
#        [276192.06 ],
#        [ 59616.027],
#        ...,
#        [ 85367.8  ],
#        [ 95896.25 ],
#        [144598.06 ]], dtype=float32)

# %%
test_pred_flatten = test_predictions.flatten()
test_pred_flatten
# Out:
# array([ 60073.45 , 276192.06 ,  59616.027, ...,  85367.8  ,  95896.25 ,
#        144598.06 ], dtype=float32)

# %%
y_test['거래금액'].values
# Out:
# array([ 30000., 200000., 137000., ...,  55300.,  76500., 107000.])

# %%
result_df = x_test.copy()
result_df['실제값'] = y_test['거래금액'].values
result_df['예측값'] = test_pred_flatten
result_df['예측오차'] = result_df['실제값']-result_df['예측값']
result_df
# Out:
#          건축년도  전체세대수  135초과세대수  전철역의수 지하철까지  주차대수  CCTV대수          연면적  \
# index
# 19070  2003.0    291         0      3     2   204    56.0   22846.9200
# 11726  2012.0    617       362      2     1   247   192.0  161663.6660
# 680    1993.0    403         0      1     2   534    77.0   83490.8600
# 1699   2020.0     66         0      1     1   405  1906.0  671682.2000
# 2213   2004.0    497         0      1     3   693   103.0   90165.2600
# ...       ...    ...       ...    ...   ...   ...     ...          ...
# 4870   1998.0    625         0      2     1   648   111.0   75000.0000
# 8685   1993.0    696         0      2     4   315    64.0   49235.1864
# 6437   2000.0    185         0      1     2   200    45.0   26179.0350
# 9947   2003.0    958         0      1     2   103   193.0  137357.8960
# 19462  2009.0    273       102      4     1   481   266.0   62049.4010
#
#            주거전용면적  편의시설수  부대·복리시설수     층     전용면적       실제값            예측값  \
# index
# ...

# %%
fig, ax = plt.subplots(1, 1, figsize=(16, 8), dpi=150)
sns.scatterplot(x='CCTV대수', y='실제값', data=result_df, label='실제값')
sns.scatterplot(x='CCTV대수', y='예측값', data=result_df, label='예측값')
sns.regplot(x='CCTV대수', y='실제값', data=result_df)
sns.regplot(x='CCTV대수', y='예측값', data=result_df)
ax.set_xlabel('CCTV대수')
ax.set_ylabel('CCTV대수')
ax.legend()
ax.grid()

plt.show()
plt.close()

# %%
result_df
# Out:
#          건축년도  전체세대수  135초과세대수  전철역의수 지하철까지  주차대수  CCTV대수          연면적  \
# index
# 19070  2003.0    291         0      3     2   204    56.0   22846.9200
# 11726  2012.0    617       362      2     1   247   192.0  161663.6660
# 680    1993.0    403         0      1     2   534    77.0   83490.8600
# 1699   2020.0     66         0      1     1   405  1906.0  671682.2000
# 2213   2004.0    497         0      1     3   693   103.0   90165.2600
# ...       ...    ...       ...    ...   ...   ...     ...          ...
# 4870   1998.0    625         0      2     1   648   111.0   75000.0000
# 8685   1993.0    696         0      2     4   315    64.0   49235.1864
# 6437   2000.0    185         0      1     2   200    45.0   26179.0350
# 9947   2003.0    958         0      1     2   103   193.0  137357.8960
# 19462  2009.0    273       102      4     1   481   266.0   62049.4010
#
#            주거전용면적  편의시설수  부대·복리시설수     층     전용면적       실제값            예측값  \
# index
# ...
